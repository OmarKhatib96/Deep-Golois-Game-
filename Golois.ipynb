# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/project.zip
# Out:
# --2020-12-23 23:11:21--  https://www.lamsade.dauphine.fr/~cazenave/project.zip
# Resolving www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)... 193.48.71.250
# Connecting to www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 275779208 (263M) [application/zip]
# Saving to: ‘project.zip.6’
#
# project.zip.6       100%[===================>] 263.00M  21.8MB/s    in 13s
#
# 2020-12-23 23:11:35 (20.2 MB/s) - ‘project.zip.6’ saved [275779208/275779208]

# %%
# !unzip project.zip
# !mv ./project/* ./
# Out:
# Archive:  project.zip
#   inflating: project/Board.h
#   inflating: project/compileMAC.sh
#   inflating: project/compile.sh
#   inflating: project/Game.h
#   inflating: project/games.data
#   inflating: project/golois.cpp
#   inflating: project/golois.cpython-38-x86_64-linux-gnu.so
#   inflating: project/golois.py
#   inflating: project/importGolois.ipynb
#   inflating: project/README
#   inflating: project/Rzone.h
#   inflating: project/test.h5
#   inflating: project/validation.data

# %%
# !pip install pybind11
# !chmod 777 ./compile.sh
# !./compile.sh
# Out:
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.6/dist-packages (2.6.1)
# In file included from golois.cpp:17:0:
# Board.h: In member function ‘bool Board::isCapturedLadder(int, int, Rzone*)’:
# Board.h:1748:8: warning: unused variable ‘n1’ [-Wunused-variable]
#     int n1 = nbLiberties (inter, liberties1, stones1, 3);
#         ^~
# Board.h:1769:12: warning: unused variable ‘n1’ [-Wunused-variable]
#         int n1 = nbLiberties (inter, liberties1, stones1, 3);
#             ^~
# Board.h: In member function ‘void Board::computeLadders(int)’:
# Board.h:1800:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (color);
#          ^~~~~
# Board.h: In member function ‘void Board::computeAllLadders(int, bool)’:
# Board.h:2046:9: warning: unused variable ‘n1’ [-Wunused-variable]
#      int n1 = nbLiberties (i, liberties1, stones1);
#          ^~
# Board.h:2082:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (i, liberties1, stones1);
#        ^~
# Board.h:2115:9: warning: unused variable ‘n1’ [-Wunused-variable]
#      int n1 = nbLiberties (i, liberties1, stones1);
#          ^~
# Board.h:2152:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (i, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::computeIsInLadder()’:
# Board.h:2223:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (s, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::computeLostLadders()’:
# Board.h:2256:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (s, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::printLadders(FILE*, int)’:
# Board.h:2268:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (color);
#          ^~~~~
# Board.h: In member function ‘bool Board::sameString(int, int)’:
# Board.h:2317:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = nbLiberties (inter, liberties, stones);
#          ^
# Board.h: In member function ‘bool Board::atariLent(int)’:
# Board.h:2636:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre - 1] == Empty)
#           ^
# Board.h:2639:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre + 1] == Empty)
#           ^
# Board.h:2642:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre - dxBoard] == Empty)
#           ^
# Board.h:2645:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre + dxBoard] == Empty)
#           ^
# Board.h: In member function ‘int Board::playAtariIfCapture(int)’:
# Board.h:3024:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::captureAdjacentAtari(int)’:
# Board.h:3080:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::captureAtari(int)’:
# Board.h:3116:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::avoidCaptureAtari(int)’:
# Board.h:3139:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::playout(int)’:
# Board.h:3275:7: warning: variable ‘m’ set but not used [-Wunused-but-set-variable]
#   Move m;
#        ^
# Board.h:3296:9: warning: unused variable ‘s’ [-Wunused-variable]
#     char s [256];
#          ^
# Board.h: In member function ‘int Board::loadSGF(FILE*)’:
# Board.h:3733:8: warning: unused variable ‘res’ [-Wunused-variable]
#     int res = sscanf (InsideBracket, "%d", &sz);
#         ^~~
# Board.h:3743:10: warning: unused variable ‘res’ [-Wunused-variable]
#       int res = sscanf (InsideBracket, "%d: %f", &i, &v);
#           ^~~
# In file included from golois.cpp:18:0:
# Game.h: In function ‘void loadGamesData(char*)’:
# Game.h:206:76: warning: format ‘%d’ expects argument of type ‘int*’, but argument 3 has type ‘short int*’ [-Wformat=]
#          fscanf (fp, "%d %d", &proGame [g] [i].inter, &proGame [g] [i].color);
#                               ~~~~~~~~~~~~~~~~~~~~~~                        ^
# Game.h:206:76: warning: format ‘%d’ expects argument of type ‘int*’, but argument 4 has type ‘char*’ [-Wformat=]
# Game.h: In function ‘void loadGamesDataVal(char*)’:
# Game.h:285:95: warning: format ‘%d’ expects argument of type ‘int*’, but argument 3 has type ‘short int*’ [-Wformat=]
#   fscanf (fp, "%d %f %d ", &proGame [g] [i].inter, &proGame [g] [i].val, &proGame [g] [i].color);
#                            ~~~~~~~~~~~~~~~~~~~~~~                                              ^
# Game.h:285:95: warning: format ‘%d’ expects argument of type ‘int*’, but argument 5 has type ‘char*’ [-Wformat=]
# golois.cpp: In lambda function:
# golois.cpp:42:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesData ("games.data");
#                                ^
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp: In lambda function:
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:155:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesData ("games.data");
#                                ^
# golois.cpp: In lambda function:
# golois.cpp:264:38: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesDataVal ("games.val.data");
#                                       ^
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# In file included from golois.cpp:18:0:
# Game.h: In function ‘void loadGamesData(char*)’:
# Game.h:193:12: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#      fscanf (fp, "%d", &nbGames);
#      ~~~~~~~^~~~~~~~~~~~~~~~~~~~
# Game.h:197:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%s ", s);
#        ~~~~~~~^~~~~~~~~~~~~~
# Game.h:200:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &nbMovesSGFGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:201:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &startGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:206:16: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#          fscanf (fp, "%d %d", &proGame [g] [i].inter, &proGame [g] [i].color);
#          ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h: In function ‘void loadGamesDataVal(char*)’:
# Game.h:278:12: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#      fscanf (fp, "%d", &nbGames);
#      ~~~~~~~^~~~~~~~~~~~~~~~~~~~
# Game.h:280:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%s ", s);
#        ~~~~~~~^~~~~~~~~~~~~~
# Game.h:282:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &nbMovesSGFGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:285:9: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   fscanf (fp, "%d %f %d ", &proGame [g] [i].inter, &proGame [g] [i].val, &proGame [g] [i].color);
#   ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# golois.cpp: In lambda function:
# golois.cpp:190:13: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#       fscanf (fp, "%d", &nbExamples);
#       ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# golois.cpp:192:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#         fscanf (fp, "%d", &indexValidation [i]);
#         ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from tensorflow.keras import layers 
from tensorflow.keras import regularizers

import golois

planes = 21   # 21 plans 19x19 les états précédents, noires, blanc
moves = 361
N = 100000
epochs = 100
batch = 200
filters = 64
#les entrées et les sorties sont fixées mais on peut modifier le réseau
input_data = np.random.randint(2, size=(N, 19, 19, planes)) #N=nombre d'exemples, pour initialise peut-être
input_data = input_data.astype ('float32')
print(input_data.shape)#added
policy = np.random.randint(moves, size=(N,))#choisi une politique aléatoire entre 1 et 361
print(policy.shape)
policy = keras.utils.to_categorical (policy)
value = np.random.randint(2, size=(N,))
value = value.astype ('float32')
print(value.shape)

end = np.random.randint(2, size=(N, 19, 19, 2))
end = end.astype ('float32')

groups = np.zeros((N, 19, 19, 1))
groups = groups.astype ('float32')

print ("getValidation", flush = True)
golois.getValidation (input_data, policy, value, end)#récupèr 10000 exemples qui n'ont pas été appris et donnés pâr le getBatch, récupèure les entrées et sortie dans la validation , c'est pour savoir si le modèle a bien appris ou pas


input = keras.Input(shape=(19, 19, planes), name='board')
x = layers.Conv2D(filters, 1, activation='relu', padding='same')(input)# on fait une convolution avec filtre 1 juste  pour  transformer le nombre de plan pour  obtenir 64 plans 
for i in range (4):#pour model résiduel
    x1 = layers.Conv2D(filters, 3, activation='relu', padding='same')(x)
    x1 = layers.BatchNormalization()(x1)
    x1 = layers.Conv2D(filters, 3, activation='swish',padding='same')(x1)
    x = layers.add([x1,x])#x is the input
    #x1 = layers.Conv2D(filters, 3, activation='tanh',padding='same')(x)

    #x1 = layers.Conv2D(filters, 3, activation='relu',padding='same')(x1)
    #x1 = layers.Conv2D(filters, 1, activation='relu')(x1)
    #x = layers.add([x1,x])#x is the input
    x = layers.ReLU()(x)
    x=layers.Dropout(0.10)(x)
    x = layers.BatchNormalization()(x)

policy_head = layers.Conv2D(1, 1, activation='swish', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(x)
policy_head = layers.Conv2D(filters, 3, activation='tanh', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
policy_head = layers.Conv2D(1, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)

#policy_head = layers.Dense(60,activation='relu')(policy_head)

#policy_head = layers.Conv2D(1, 3, activation='swish', padding='same')(policy_head)
#policy_head = layers.Conv2D(16, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
#policy_head = layers.Conv2D(8, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)

policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)

'''
policy_head = layers.Conv2D(1, 1, activation='swish', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(x)
#policy_head = layers.MaxPooling2D()(policy_head)
policy_head = layers.Conv2D(filters, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
#policy_head = layers.MaxPooling2D()(policy_head)
policy_head = layers.Conv2D(1, 3, activation='swish', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0005))(policy_head)

#policy_head = layers.Dense(60,activation='relu')(policy_head)

#policy_head = layers.Conv2D(1, 3, activation='swish', padding='same')(policy_head)
#policy_head = layers.Conv2D(16, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
#policy_head = layers.Conv2D(8, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)

policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)
#on est entrain d'effectuer un apprentissage sur 2 niveaux: au niveau de la policy(laquelle)+de la valeur(lequel va gagner)
'''

value_head = layers.Conv2D(80, 3, activation='swish', padding='same')(x)
value_head=layers.Dropout(0.15)(value_head)
value_head = layers.GlobalAveragePooling2D()(value_head)
value_head = layers.Dense(30, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(value_head)
#value_head = layers.Dense(50, activation='mish', kernel_regularizer=regularizers.l2(0.0001))(value_head)
value_head=layers.Dropout(0.10)(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0008))(value_head)




'''
value_head = layers.Conv2D(60, 3, activation='relu', padding='same')(x)
#value_head = layers.GlobalAveragePooling2D()(value_head)
value_head = layers.Dense(40, activation='swish', kernel_regularizer=regularizers.l2(0.0003))(value_head)
value_head=layers.Dropout(0.10)(value_head)
value_head = layers.Dense(30, activation='swish', kernel_regularizer=regularizers.l2(0.0003))(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0008))(value_head)
'''
model = keras.Model(inputs=input, outputs=[policy_head, value_head])

model.summary ()

model.compile(optimizer=keras.optimizers.SGD(lr=0.010, momentum=0.95),
              loss={'policy': 'categorical_crossentropy', 'value': 'binary_crossentropy'},
              loss_weights={'policy' : 1.0, 'value' : 5.0},
              metrics={'policy': 'categorical_accuracy', 'value': 'mse'})

for i in range (1, epochs + 1):
    print ('epoch ' + str (i))
    golois.getBatch (input_data, policy, value, end, groups)#une partie jouée par catago , remplit les tenseurs avec tenseurs
    history = model.fit(input_data,
                        {'policy': policy, 'value': value}, 
                        epochs=1, batch_size=batch)
    if (i % 10 == 0):
        golois.getValidation (input_data, policy, value, end)
        val = model.evaluate (input_data,
                              [policy, value], verbose = 0, batch_size=batch)#mse sur les données de validations (su rles données qui n'ont jamais été)
        print ("val =", val)

model.save ('test.h5')
# Out:
# (100000, 19, 19, 21)
# (100000,)
# (100000,)
# getValidation
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# board (InputLayer)              [(None, 19, 19, 21)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 19, 19, 64)   1408        board[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 19, 19, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 19, 19, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 19, 19, 64)   0           conv2d_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 19, 19, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 19, 19, 64)   0           re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 19, 19, 64)   256         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 19, 19, 64)   0           conv2d_4[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 19, 19, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 19, 19, 64)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 19, 19, 64)   256         dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 19, 19, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 64)   0           conv2d_6[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 19, 19, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 19, 19, 64)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 19, 19, 64)   256         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 19, 19, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 64)   0           conv2d_8[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 19, 19, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 19, 19, 64)   0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 19, 19, 64)   256         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 19, 19, 80)   46160       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 19, 19, 1)    64          batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 19, 19, 80)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 19, 19, 64)   576         conv2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 80)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 19, 19, 1)    576         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           2430        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 361)          0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30)           0           dense[0][0]
# __________________________________________________________________________________________________
# policy (Activation)             (None, 361)          0           flatten[0][0]
# __________________________________________________________________________________________________
# value (Dense)                   (None, 1)            31          dropout_5[0][0]
# ==================================================================================================
# Total params: 348,717
# Trainable params: 347,693
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# epoch 1
# 500/500 [==============================] - 45s 73ms/step - loss: 8.0815 - policy_loss: 4.6008 - value_loss: 0.6950 - policy_categorical_accuracy: 0.1208 - value_mse: 0.2509
# epoch 2
# 500/500 [==============================] - 37s 74ms/step - loss: 6.4998 - policy_loss: 3.0884 - value_loss: 0.6811 - policy_categorical_accuracy: 0.2906 - value_mse: 0.2441
# epoch 3
# 500/500 [==============================] - 38s 75ms/step - loss: 6.3430 - policy_loss: 2.9615 - value_loss: 0.6751 - policy_categorical_accuracy: 0.3099 - value_mse: 0.2413
# epoch 4
# 500/500 [==============================] - 37s 74ms/step - loss: 6.2681 - policy_loss: 2.9043 - value_loss: 0.6715 - policy_categorical_accuracy: 0.3196 - value_mse: 0.2397
# epoch 5
# 435/500 [=========================>....] - ETA: 4s - loss: 6.1985 - policy_loss: 2.8569 - value_loss: 0.6671 - policy_categorical_accuracy: 0.3255 - value_mse: 0.2377

# %%
from google.colab import files
files.download('test.h5')
