# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/project.zip
# Out:
# --2020-12-23 23:11:21--  https://www.lamsade.dauphine.fr/~cazenave/project.zip
# Resolving www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)... 193.48.71.250
# Connecting to www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 275779208 (263M) [application/zip]
# Saving to: ‘project.zip.6’
#
# project.zip.6       100%[===================>] 263.00M  21.8MB/s    in 13s
#
# 2020-12-23 23:11:35 (20.2 MB/s) - ‘project.zip.6’ saved [275779208/275779208]

# %%
# !unzip project.zip
# !mv ./project/* ./
# Out:
# Archive:  project.zip
#   inflating: project/Board.h
#   inflating: project/compileMAC.sh
#   inflating: project/compile.sh
#   inflating: project/Game.h
#   inflating: project/games.data
#   inflating: project/golois.cpp
#   inflating: project/golois.cpython-38-x86_64-linux-gnu.so
#   inflating: project/golois.py
#   inflating: project/importGolois.ipynb
#   inflating: project/README
#   inflating: project/Rzone.h
#   inflating: project/test.h5
#   inflating: project/validation.data

# %%
# !pip install pybind11
# !chmod 777 ./compile.sh
# !./compile.sh
# Out:
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.6/dist-packages (2.6.1)
# In file included from golois.cpp:17:0:
# Board.h: In member function ‘bool Board::isCapturedLadder(int, int, Rzone*)’:
# Board.h:1748:8: warning: unused variable ‘n1’ [-Wunused-variable]
#     int n1 = nbLiberties (inter, liberties1, stones1, 3);
#         ^~
# Board.h:1769:12: warning: unused variable ‘n1’ [-Wunused-variable]
#         int n1 = nbLiberties (inter, liberties1, stones1, 3);
#             ^~
# Board.h: In member function ‘void Board::computeLadders(int)’:
# Board.h:1800:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (color);
#          ^~~~~
# Board.h: In member function ‘void Board::computeAllLadders(int, bool)’:
# Board.h:2046:9: warning: unused variable ‘n1’ [-Wunused-variable]
#      int n1 = nbLiberties (i, liberties1, stones1);
#          ^~
# Board.h:2082:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (i, liberties1, stones1);
#        ^~
# Board.h:2115:9: warning: unused variable ‘n1’ [-Wunused-variable]
#      int n1 = nbLiberties (i, liberties1, stones1);
#          ^~
# Board.h:2152:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (i, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::computeIsInLadder()’:
# Board.h:2223:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (s, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::computeLostLadders()’:
# Board.h:2256:7: warning: unused variable ‘n1’ [-Wunused-variable]
#    int n1 = nbLiberties (s, liberties1, stones1);
#        ^~
# Board.h: In member function ‘void Board::printLadders(FILE*, int)’:
# Board.h:2268:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (color);
#          ^~~~~
# Board.h: In member function ‘bool Board::sameString(int, int)’:
# Board.h:2317:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = nbLiberties (inter, liberties, stones);
#          ^
# Board.h: In member function ‘bool Board::atariLent(int)’:
# Board.h:2636:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre - 1] == Empty)
#           ^
# Board.h:2639:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre + 1] == Empty)
#           ^
# Board.h:2642:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre - dxBoard] == Empty)
#           ^
# Board.h:2645:10: warning: suggest explicit braces to avoid ambiguous ‘else’ [-Wdangling-else]
#        if (board [pierre + dxBoard] == Empty)
#           ^
# Board.h: In member function ‘int Board::playAtariIfCapture(int)’:
# Board.h:3024:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::captureAdjacentAtari(int)’:
# Board.h:3080:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::captureAtari(int)’:
# Board.h:3116:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::avoidCaptureAtari(int)’:
# Board.h:3139:9: warning: unused variable ‘other’ [-Wunused-variable]
#      int other = opponent (couleur);
#          ^~~~~
# Board.h: In member function ‘int Board::playout(int)’:
# Board.h:3275:7: warning: variable ‘m’ set but not used [-Wunused-but-set-variable]
#   Move m;
#        ^
# Board.h:3296:9: warning: unused variable ‘s’ [-Wunused-variable]
#     char s [256];
#          ^
# Board.h: In member function ‘int Board::loadSGF(FILE*)’:
# Board.h:3733:8: warning: unused variable ‘res’ [-Wunused-variable]
#     int res = sscanf (InsideBracket, "%d", &sz);
#         ^~~
# Board.h:3743:10: warning: unused variable ‘res’ [-Wunused-variable]
#       int res = sscanf (InsideBracket, "%d: %f", &i, &v);
#           ^~~
# In file included from golois.cpp:18:0:
# Game.h: In function ‘void loadGamesData(char*)’:
# Game.h:206:76: warning: format ‘%d’ expects argument of type ‘int*’, but argument 3 has type ‘short int*’ [-Wformat=]
#          fscanf (fp, "%d %d", &proGame [g] [i].inter, &proGame [g] [i].color);
#                               ~~~~~~~~~~~~~~~~~~~~~~                        ^
# Game.h:206:76: warning: format ‘%d’ expects argument of type ‘int*’, but argument 4 has type ‘char*’ [-Wformat=]
# Game.h: In function ‘void loadGamesDataVal(char*)’:
# Game.h:285:95: warning: format ‘%d’ expects argument of type ‘int*’, but argument 3 has type ‘short int*’ [-Wformat=]
#   fscanf (fp, "%d %f %d ", &proGame [g] [i].inter, &proGame [g] [i].val, &proGame [g] [i].color);
#                            ~~~~~~~~~~~~~~~~~~~~~~                                              ^
# Game.h:285:95: warning: format ‘%d’ expects argument of type ‘int*’, but argument 5 has type ‘char*’ [-Wformat=]
# golois.cpp: In lambda function:
# golois.cpp:42:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesData ("games.data");
#                                ^
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:61:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp: In lambda function:
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:147:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:155:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesData ("games.data");
#                                ^
# golois.cpp: In lambda function:
# golois.cpp:264:38: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#     loadGamesDataVal ("games.val.data");
#                                       ^
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
#   fprintf (stderr, "r.shape = (%d, %d, %d, %d)\n", r.shape (0), r.shape (1), r.shape (2), r.shape (3));
#                                                    ~~~~~~~~~~~                                       ^
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# golois.cpp:272:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘pybind11::ssize_t {aka long int}’ [-Wformat=]
# In file included from golois.cpp:18:0:
# Game.h: In function ‘void loadGamesData(char*)’:
# Game.h:193:12: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#      fscanf (fp, "%d", &nbGames);
#      ~~~~~~~^~~~~~~~~~~~~~~~~~~~
# Game.h:197:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%s ", s);
#        ~~~~~~~^~~~~~~~~~~~~~
# Game.h:200:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &nbMovesSGFGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:201:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &startGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:206:16: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#          fscanf (fp, "%d %d", &proGame [g] [i].inter, &proGame [g] [i].color);
#          ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h: In function ‘void loadGamesDataVal(char*)’:
# Game.h:278:12: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#      fscanf (fp, "%d", &nbGames);
#      ~~~~~~~^~~~~~~~~~~~~~~~~~~~
# Game.h:280:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%s ", s);
#        ~~~~~~~^~~~~~~~~~~~~~
# Game.h:282:14: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#        fscanf (fp, "%d", &nbMovesSGFGame [g]);
#        ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Game.h:285:9: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   fscanf (fp, "%d %f %d ", &proGame [g] [i].inter, &proGame [g] [i].val, &proGame [g] [i].color);
#   ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# golois.cpp: In lambda function:
# golois.cpp:190:13: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#       fscanf (fp, "%d", &nbExamples);
#       ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# golois.cpp:192:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#         fscanf (fp, "%d", &indexValidation [i]);
#         ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from tensorflow.keras import layers 
from tensorflow.keras import regularizers

import golois

planes = 21   # 21 plans 19x19 les états précédents, noires, blanc
moves = 361
N = 100000
epochs = 100
batch = 200
filters = 64
#les entrées et les sorties sont fixées mais on peut modifier le réseau
input_data = np.random.randint(2, size=(N, 19, 19, planes)) #N=nombre d'exemples, pour initialise peut-être
input_data = input_data.astype ('float32')
print(input_data.shape)#added
policy = np.random.randint(moves, size=(N,))#choisi une politique aléatoire entre 1 et 361
print(policy.shape)
policy = keras.utils.to_categorical (policy)
value = np.random.randint(2, size=(N,))
value = value.astype ('float32')
print(value.shape)

end = np.random.randint(2, size=(N, 19, 19, 2))
end = end.astype ('float32')

groups = np.zeros((N, 19, 19, 1))
groups = groups.astype ('float32')

print ("getValidation", flush = True)
golois.getValidation (input_data, policy, value, end)#récupèr 10000 exemples qui n'ont pas été appris et donnés pâr le getBatch, récupèure les entrées et sortie dans la validation , c'est pour savoir si le modèle a bien appris ou pas


input = keras.Input(shape=(19, 19, planes), name='board')
x = layers.Conv2D(filters, 1, activation='relu', padding='same')(input)# on fait une convolution avec filtre 1 juste  pour  transformer le nombre de plan pour  obtenir 64 plans 
for i in range (4):#pour model résiduel
    x1 = layers.Conv2D(filters, 3, activation='relu', padding='same')(x)
    x1 = layers.BatchNormalization()(x1)
    x1 = layers.Conv2D(filters, 3, activation='swish',padding='same')(x1)
    x = layers.add([x1,x])#x is the input
    x = layers.ReLU()(x)
    x=layers.Dropout(0.10)(x)
    x = layers.BatchNormalization()(x)

policy_head = layers.Conv2D(1, 1, activation='swish', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(x)
policy_head = layers.Conv2D(filters, 3, activation='tanh', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
policy_head = layers.Conv2D(1, 3, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)

policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)



value_head = layers.Conv2D(80, 3, activation='swish', padding='same')(x)
value_head=layers.Dropout(0.15)(value_head)
value_head = layers.GlobalAveragePooling2D()(value_head)
value_head = layers.Dense(30, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(value_head)
value_head=layers.Dropout(0.10)(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0008))(value_head)




model = keras.Model(inputs=input, outputs=[policy_head, value_head])

model.summary ()

model.compile(optimizer=keras.optimizers.SGD(lr=0.010, momentum=0.95),
              loss={'policy': 'categorical_crossentropy', 'value': 'binary_crossentropy'},
              loss_weights={'policy' : 1.0, 'value' : 5.0},
              metrics={'policy': 'categorical_accuracy', 'value': 'mse'})

for i in range (1, epochs + 1):
    print ('epoch ' + str (i))
    golois.getBatch (input_data, policy, value, end, groups)#une partie jouée par catago , remplit les tenseurs avec tenseurs
    history = model.fit(input_data,
                        {'policy': policy, 'value': value}, 
                        epochs=1, batch_size=batch)
    if (i % 10 == 0):
        golois.getValidation (input_data, policy, value, end)
        val = model.evaluate (input_data,
                              [policy, value], verbose = 0, batch_size=batch)#mse sur les données de validations (su rles données qui n'ont jamais été)
        print ("val =", val)

model.save ('test.h5')
# Out:
# (100000, 19, 19, 21)
# (100000,)
# (100000,)
# getValidation
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# board (InputLayer)              [(None, 19, 19, 21)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 19, 19, 64)   1408        board[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 19, 19, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 19, 19, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 19, 19, 64)   0           conv2d_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 19, 19, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 19, 19, 64)   0           re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 19, 19, 64)   256         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 19, 19, 64)   0           conv2d_4[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 19, 19, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 19, 19, 64)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 19, 19, 64)   256         dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 19, 19, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 64)   0           conv2d_6[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 19, 19, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 19, 19, 64)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 19, 19, 64)   256         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 19, 19, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 19, 19, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 64)   0           conv2d_8[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 19, 19, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 19, 19, 64)   0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 19, 19, 64)   256         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 19, 19, 80)   46160       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 19, 19, 1)    64          batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 19, 19, 80)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 19, 19, 64)   576         conv2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 80)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 19, 19, 1)    576         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           2430        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 361)          0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30)           0           dense[0][0]
# __________________________________________________________________________________________________
# policy (Activation)             (None, 361)          0           flatten[0][0]
# __________________________________________________________________________________________________
# value (Dense)                   (None, 1)            31          dropout_5[0][0]
# ==================================================================================================
# Total params: 348,717
# Trainable params: 347,693
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# epoch 1
# 500/500 [==============================] - 45s 73ms/step - loss: 8.0815 - policy_loss: 4.6008 - value_loss: 0.6950 - policy_categorical_accuracy: 0.1208 - value_mse: 0.2509
# epoch 2
# 500/500 [==============================] - 37s 74ms/step - loss: 6.4998 - policy_loss: 3.0884 - value_loss: 0.6811 - policy_categorical_accuracy: 0.2906 - value_mse: 0.2441
# epoch 3
# 500/500 [==============================] - 38s 75ms/step - loss: 6.3430 - policy_loss: 2.9615 - value_loss: 0.6751 - policy_categorical_accuracy: 0.3099 - value_mse: 0.2413
# epoch 4
# 500/500 [==============================] - 37s 74ms/step - loss: 6.2681 - policy_loss: 2.9043 - value_loss: 0.6715 - policy_categorical_accuracy: 0.3196 - value_mse: 0.2397
# epoch 5
# 500/500 [==============================] - 37s 75ms/step - loss: 6.1917 - policy_loss: 2.8509 - value_loss: 0.6669 - policy_categorical_accuracy: 0.3256 - value_mse: 0.2376
# epoch 6
# 500/500 [==============================] - 37s 74ms/step - loss: 6.1460 - policy_loss: 2.8135 - value_loss: 0.6652 - policy_categorical_accuracy: 0.3307 - value_mse: 0.2369
# epoch 7
# 500/500 [==============================] - 37s 74ms/step - loss: 6.1013 - policy_loss: 2.7795 - value_loss: 0.6631 - policy_categorical_accuracy: 0.3351 - value_mse: 0.2359
# epoch 8
# 500/500 [==============================] - 37s 74ms/step - loss: 6.0823 - policy_loss: 2.7631 - value_loss: 0.6626 - policy_categorical_accuracy: 0.3377 - value_mse: 0.2357
# epoch 9
# 500/500 [==============================] - 37s 74ms/step - loss: 6.0296 - policy_loss: 2.7221 - value_loss: 0.6602 - policy_categorical_accuracy: 0.3451 - value_mse: 0.2347
# epoch 10
# 500/500 [==============================] - 37s 74ms/step - loss: 6.0157 - policy_loss: 2.7076 - value_loss: 0.6603 - policy_categorical_accuracy: 0.3456 - value_mse: 0.2348
# val = [5.916738986968994, 2.6459925174713135, 0.652802050113678, 0.3567799925804138, 0.23142436146736145]
# epoch 11
# 500/500 [==============================] - 37s 74ms/step - loss: 6.0039 - policy_loss: 2.7045 - value_loss: 0.6585 - policy_categorical_accuracy: 0.3457 - value_mse: 0.2341
# epoch 12
# 500/500 [==============================] - 37s 74ms/step - loss: 5.9765 - policy_loss: 2.6836 - value_loss: 0.6572 - policy_categorical_accuracy: 0.3477 - value_mse: 0.2334
# epoch 13
# 500/500 [==============================] - 37s 74ms/step - loss: 5.9539 - policy_loss: 2.6692 - value_loss: 0.6555 - policy_categorical_accuracy: 0.3496 - value_mse: 0.2327
# epoch 14
# 500/500 [==============================] - 37s 75ms/step - loss: 5.9474 - policy_loss: 2.6590 - value_loss: 0.6562 - policy_categorical_accuracy: 0.3533 - value_mse: 0.2330
# epoch 15
# 500/500 [==============================] - 37s 75ms/step - loss: 5.9351 - policy_loss: 2.6507 - value_loss: 0.6555 - policy_categorical_accuracy: 0.3532 - value_mse: 0.2326
# epoch 16
# 500/500 [==============================] - 37s 74ms/step - loss: 5.9096 - policy_loss: 2.6359 - value_loss: 0.6533 - policy_categorical_accuracy: 0.3570 - value_mse: 0.2318
# epoch 17
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8978 - policy_loss: 2.6281 - value_loss: 0.6525 - policy_categorical_accuracy: 0.3569 - value_mse: 0.2315
# epoch 18
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8675 - policy_loss: 2.6133 - value_loss: 0.6494 - policy_categorical_accuracy: 0.3592 - value_mse: 0.2301
# epoch 19
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8828 - policy_loss: 2.6091 - value_loss: 0.6532 - policy_categorical_accuracy: 0.3590 - value_mse: 0.2317
# epoch 20
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8683 - policy_loss: 2.6047 - value_loss: 0.6512 - policy_categorical_accuracy: 0.3598 - value_mse: 0.2309
# val = [5.82678747177124, 2.5353567600250244, 0.656792402267456, 0.3700900077819824, 0.23315243422985077]
# epoch 21
# 500/500 [==============================] - 38s 76ms/step - loss: 5.8634 - policy_loss: 2.5998 - value_loss: 0.6512 - policy_categorical_accuracy: 0.3592 - value_mse: 0.2310
# epoch 22
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8508 - policy_loss: 2.5939 - value_loss: 0.6498 - policy_categorical_accuracy: 0.3628 - value_mse: 0.2304
# epoch 23
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8548 - policy_loss: 2.5981 - value_loss: 0.6498 - policy_categorical_accuracy: 0.3593 - value_mse: 0.2304
# epoch 24
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8235 - policy_loss: 2.5733 - value_loss: 0.6485 - policy_categorical_accuracy: 0.3652 - value_mse: 0.2298
# epoch 25
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8297 - policy_loss: 2.5743 - value_loss: 0.6495 - policy_categorical_accuracy: 0.3632 - value_mse: 0.2301
# epoch 26
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8221 - policy_loss: 2.5688 - value_loss: 0.6491 - policy_categorical_accuracy: 0.3625 - value_mse: 0.2300
# epoch 27
# 500/500 [==============================] - 38s 75ms/step - loss: 5.8177 - policy_loss: 2.5703 - value_loss: 0.6479 - policy_categorical_accuracy: 0.3652 - value_mse: 0.2296
# epoch 28
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7935 - policy_loss: 2.5583 - value_loss: 0.6454 - policy_categorical_accuracy: 0.3659 - value_mse: 0.2284
# epoch 29
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7996 - policy_loss: 2.5580 - value_loss: 0.6467 - policy_categorical_accuracy: 0.3646 - value_mse: 0.2290
# epoch 30
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7924 - policy_loss: 2.5456 - value_loss: 0.6477 - policy_categorical_accuracy: 0.3694 - value_mse: 0.2295
# val = [5.719906330108643, 2.4763803482055664, 0.6470789313316345, 0.37973999977111816, 0.2291833758354187]
# epoch 31
# 500/500 [==============================] - 38s 76ms/step - loss: 5.7862 - policy_loss: 2.5447 - value_loss: 0.6467 - policy_categorical_accuracy: 0.3676 - value_mse: 0.2290
# epoch 32
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7713 - policy_loss: 2.5427 - value_loss: 0.6441 - policy_categorical_accuracy: 0.3685 - value_mse: 0.2280
# epoch 33
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7807 - policy_loss: 2.5508 - value_loss: 0.6443 - policy_categorical_accuracy: 0.3671 - value_mse: 0.2280
# epoch 34
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7670 - policy_loss: 2.5396 - value_loss: 0.6438 - policy_categorical_accuracy: 0.3674 - value_mse: 0.2278
# epoch 35
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7664 - policy_loss: 2.5388 - value_loss: 0.6438 - policy_categorical_accuracy: 0.3677 - value_mse: 0.2278
# epoch 36
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7751 - policy_loss: 2.5505 - value_loss: 0.6432 - policy_categorical_accuracy: 0.3650 - value_mse: 0.2276
# epoch 37
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7462 - policy_loss: 2.5253 - value_loss: 0.6425 - policy_categorical_accuracy: 0.3685 - value_mse: 0.2273
# epoch 38
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7555 - policy_loss: 2.5326 - value_loss: 0.6429 - policy_categorical_accuracy: 0.3689 - value_mse: 0.2276
# epoch 39
# 500/500 [==============================] - 38s 75ms/step - loss: 5.7493 - policy_loss: 2.5198 - value_loss: 0.6442 - policy_categorical_accuracy: 0.3713 - value_mse: 0.2280
# epoch 40
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7468 - policy_loss: 2.5115 - value_loss: 0.6454 - policy_categorical_accuracy: 0.3700 - value_mse: 0.2285
# val = [5.7133307456970215, 2.4439213275909424, 0.6521793007850647, 0.3843599855899811, 0.23170554637908936]
# epoch 41
# 500/500 [==============================] - 37s 75ms/step - loss: 5.7195 - policy_loss: 2.5070 - value_loss: 0.6408 - policy_categorical_accuracy: 0.3745 - value_mse: 0.2265
# epoch 42
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7342 - policy_loss: 2.5143 - value_loss: 0.6422 - policy_categorical_accuracy: 0.3717 - value_mse: 0.2271
# epoch 43
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7131 - policy_loss: 2.4998 - value_loss: 0.6409 - policy_categorical_accuracy: 0.3742 - value_mse: 0.2267
# epoch 44
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7200 - policy_loss: 2.5116 - value_loss: 0.6399 - policy_categorical_accuracy: 0.3723 - value_mse: 0.2263
# epoch 45
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7228 - policy_loss: 2.5070 - value_loss: 0.6414 - policy_categorical_accuracy: 0.3733 - value_mse: 0.2269
# epoch 46
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7288 - policy_loss: 2.5156 - value_loss: 0.6409 - policy_categorical_accuracy: 0.3727 - value_mse: 0.2266
# epoch 47
# 500/500 [==============================] - 37s 74ms/step - loss: 5.6940 - policy_loss: 2.4851 - value_loss: 0.6401 - policy_categorical_accuracy: 0.3782 - value_mse: 0.2263
# epoch 48
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7151 - policy_loss: 2.4973 - value_loss: 0.6419 - policy_categorical_accuracy: 0.3757 - value_mse: 0.2270
# epoch 49
# 500/500 [==============================] - 37s 74ms/step - loss: 5.6988 - policy_loss: 2.4964 - value_loss: 0.6387 - policy_categorical_accuracy: 0.3724 - value_mse: 0.2258
# epoch 50
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7040 - policy_loss: 2.4943 - value_loss: 0.6402 - policy_categorical_accuracy: 0.3751 - value_mse: 0.2264
# val = [5.7408061027526855, 2.4274299144744873, 0.6609127521514893, 0.38517001271247864, 0.2346198409795761]
# epoch 51
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6989 - policy_loss: 2.4972 - value_loss: 0.6386 - policy_categorical_accuracy: 0.3749 - value_mse: 0.2257
# epoch 52
# 500/500 [==============================] - 37s 74ms/step - loss: 5.7023 - policy_loss: 2.4935 - value_loss: 0.6400 - policy_categorical_accuracy: 0.3775 - value_mse: 0.2262
# epoch 53
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6929 - policy_loss: 2.4894 - value_loss: 0.6389 - policy_categorical_accuracy: 0.3755 - value_mse: 0.2258
# epoch 54
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6889 - policy_loss: 2.4872 - value_loss: 0.6385 - policy_categorical_accuracy: 0.3776 - value_mse: 0.2259
# epoch 55
# 500/500 [==============================] - 37s 74ms/step - loss: 5.6943 - policy_loss: 2.4960 - value_loss: 0.6379 - policy_categorical_accuracy: 0.3747 - value_mse: 0.2254
# epoch 56
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6722 - policy_loss: 2.4780 - value_loss: 0.6370 - policy_categorical_accuracy: 0.3777 - value_mse: 0.2250
# epoch 57
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6838 - policy_loss: 2.4870 - value_loss: 0.6375 - policy_categorical_accuracy: 0.3760 - value_mse: 0.2253
# epoch 58
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6703 - policy_loss: 2.4778 - value_loss: 0.6367 - policy_categorical_accuracy: 0.3764 - value_mse: 0.2249
# epoch 59
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6767 - policy_loss: 2.4834 - value_loss: 0.6369 - policy_categorical_accuracy: 0.3758 - value_mse: 0.2249
# epoch 60
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6808 - policy_loss: 2.4768 - value_loss: 0.6390 - policy_categorical_accuracy: 0.3780 - value_mse: 0.2258
# val = [5.66356897354126, 2.410228967666626, 0.6488730311393738, 0.39190998673439026, 0.23017115890979767]
# epoch 61
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6776 - policy_loss: 2.4807 - value_loss: 0.6376 - policy_categorical_accuracy: 0.3776 - value_mse: 0.2251
# epoch 62
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6508 - policy_loss: 2.4723 - value_loss: 0.6338 - policy_categorical_accuracy: 0.3789 - value_mse: 0.2239
# epoch 63
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6586 - policy_loss: 2.4694 - value_loss: 0.6360 - policy_categorical_accuracy: 0.3792 - value_mse: 0.2246
# epoch 64
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6519 - policy_loss: 2.4704 - value_loss: 0.6344 - policy_categorical_accuracy: 0.3786 - value_mse: 0.2240
# epoch 65
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6269 - policy_loss: 2.4582 - value_loss: 0.6318 - policy_categorical_accuracy: 0.3808 - value_mse: 0.2229
# epoch 66
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6579 - policy_loss: 2.4737 - value_loss: 0.6349 - policy_categorical_accuracy: 0.3777 - value_mse: 0.2244
# epoch 67
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6572 - policy_loss: 2.4748 - value_loss: 0.6346 - policy_categorical_accuracy: 0.3773 - value_mse: 0.2240
# epoch 68
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6534 - policy_loss: 2.4598 - value_loss: 0.6368 - policy_categorical_accuracy: 0.3808 - value_mse: 0.2250
# epoch 69
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6393 - policy_loss: 2.4650 - value_loss: 0.6329 - policy_categorical_accuracy: 0.3792 - value_mse: 0.2235
# epoch 70
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6472 - policy_loss: 2.4679 - value_loss: 0.6339 - policy_categorical_accuracy: 0.3765 - value_mse: 0.2239
# val = [5.615143775939941, 2.3905270099639893, 0.6429916024208069, 0.39083999395370483, 0.2274281233549118]
# epoch 71
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6321 - policy_loss: 2.4617 - value_loss: 0.6322 - policy_categorical_accuracy: 0.3798 - value_mse: 0.2230
# epoch 72
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6370 - policy_loss: 2.4552 - value_loss: 0.6344 - policy_categorical_accuracy: 0.3801 - value_mse: 0.2240
# epoch 73
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6499 - policy_loss: 2.4652 - value_loss: 0.6350 - policy_categorical_accuracy: 0.3795 - value_mse: 0.2244
# epoch 74
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6327 - policy_loss: 2.4648 - value_loss: 0.6315 - policy_categorical_accuracy: 0.3803 - value_mse: 0.2229
# epoch 75
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6465 - policy_loss: 2.4692 - value_loss: 0.6335 - policy_categorical_accuracy: 0.3773 - value_mse: 0.2236
# epoch 76
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6131 - policy_loss: 2.4414 - value_loss: 0.6323 - policy_categorical_accuracy: 0.3844 - value_mse: 0.2231
# epoch 77
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6139 - policy_loss: 2.4564 - value_loss: 0.6295 - policy_categorical_accuracy: 0.3803 - value_mse: 0.2221
# epoch 78
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6232 - policy_loss: 2.4592 - value_loss: 0.6308 - policy_categorical_accuracy: 0.3773 - value_mse: 0.2226
# epoch 79
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6166 - policy_loss: 2.4448 - value_loss: 0.6323 - policy_categorical_accuracy: 0.3819 - value_mse: 0.2232
# epoch 80
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6116 - policy_loss: 2.4476 - value_loss: 0.6307 - policy_categorical_accuracy: 0.3831 - value_mse: 0.2226
# val = [5.499865531921387, 2.3823328018188477, 0.6213990449905396, 0.3939400017261505, 0.21856939792633057]
# epoch 81
# 500/500 [==============================] - 38s 76ms/step - loss: 5.6092 - policy_loss: 2.4539 - value_loss: 0.6290 - policy_categorical_accuracy: 0.3805 - value_mse: 0.2218
# epoch 82
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6220 - policy_loss: 2.4516 - value_loss: 0.6320 - policy_categorical_accuracy: 0.3819 - value_mse: 0.2230
# epoch 83
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6017 - policy_loss: 2.4482 - value_loss: 0.6286 - policy_categorical_accuracy: 0.3822 - value_mse: 0.2217
# epoch 84
# 500/500 [==============================] - 38s 75ms/step - loss: 5.6116 - policy_loss: 2.4547 - value_loss: 0.6293 - policy_categorical_accuracy: 0.3810 - value_mse: 0.2219
# epoch 85
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6187 - policy_loss: 2.4516 - value_loss: 0.6313 - policy_categorical_accuracy: 0.3806 - value_mse: 0.2227
# epoch 86
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6020 - policy_loss: 2.4439 - value_loss: 0.6295 - policy_categorical_accuracy: 0.3815 - value_mse: 0.2220
# epoch 87
# 500/500 [==============================] - 37s 75ms/step - loss: 5.5990 - policy_loss: 2.4441 - value_loss: 0.6289 - policy_categorical_accuracy: 0.3832 - value_mse: 0.2219
# epoch 88
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6011 - policy_loss: 2.4436 - value_loss: 0.6293 - policy_categorical_accuracy: 0.3836 - value_mse: 0.2221
# epoch 89
# 500/500 [==============================] - 37s 75ms/step - loss: 5.5834 - policy_loss: 2.4376 - value_loss: 0.6270 - policy_categorical_accuracy: 0.3799 - value_mse: 0.2211
# epoch 90
# 500/500 [==============================] - 37s 75ms/step - loss: 5.6025 - policy_loss: 2.4464 - value_loss: 0.6290 - policy_categorical_accuracy: 0.3820 - value_mse: 0.2219
# val = [5.608353614807129, 2.3917243480682373, 0.6411568522453308, 0.39289000630378723, 0.2255140244960785]
# epoch 91
# 500/500 [==============================] - 37s 75ms/step - loss: 5.5951 - policy_loss: 2.4408 - value_loss: 0.6287 - policy_categorical_accuracy: 0.3814 - value_mse: 0.2217
# epoch 92
# 500/500 [==============================] - 37s 74ms/step - loss: 5.6029 - policy_loss: 2.4448 - value_loss: 0.6294 - policy_categorical_accuracy: 0.3826 - value_mse: 0.2221
# epoch 93
# 500/500 [==============================] - 37s 74ms/step - loss: 5.5890 - policy_loss: 2.4483 - value_loss: 0.6259 - policy_categorical_accuracy: 0.3810 - value_mse: 0.2206
# epoch 94
# 500/500 [==============================] - 37s 74ms/step - loss: 5.5954 - policy_loss: 2.4408 - value_loss: 0.6287 - policy_categorical_accuracy: 0.3810 - value_mse: 0.2218
# epoch 95
# 500/500 [==============================] - 37s 74ms/step - loss: 5.5991 - policy_loss: 2.4371 - value_loss: 0.6302 - policy_categorical_accuracy: 0.3851 - value_mse: 0.2223
# epoch 96
# 500/500 [==============================] - 37s 74ms/step - loss: 5.5872 - policy_loss: 2.4416 - value_loss: 0.6270 - policy_categorical_accuracy: 0.3821 - value_mse: 0.2209
# epoch 97
# 500/500 [==============================] - 38s 75ms/step - loss: 5.5906 - policy_loss: 2.4405 - value_loss: 0.6278 - policy_categorical_accuracy: 0.3831 - value_mse: 0.2214
# epoch 98
# 500/500 [==============================] - 38s 75ms/step - loss: 5.5885 - policy_loss: 2.4422 - value_loss: 0.6270 - policy_categorical_accuracy: 0.3835 - value_mse: 0.2212
# epoch 99
# 500/500 [==============================] - 37s 75ms/step - loss: 5.5722 - policy_loss: 2.4337 - value_loss: 0.6255 - policy_categorical_accuracy: 0.3839 - value_mse: 0.2205
# epoch 100
# 500/500 [==============================] - 38s 75ms/step - loss: 5.5785 - policy_loss: 2.4332 - value_loss: 0.6268 - policy_categorical_accuracy: 0.3836 - value_mse: 0.2209
# val = [5.5338945388793945, 2.368579149246216, 0.6308509111404419, 0.39427998661994934, 0.22299303114414215]

# %%
from google.colab import files
files.download('test.h5')
